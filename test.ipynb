# %%
from models.yolo import Model

m = Model('models/yolov5_mobilenetv3small.yaml', ch=3, nc=3)  
print(m)
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1    927008  MobileNetV3Small                        [True]
#   1                 0  1         0  models.common.Select                    [0, 24]
#   2                 0  1         0  models.common.Select                    [1, 40]
#   3                 0  1         0  models.common.Select                    [2, 576]
#   4                 3  1    757312  models.common.SPPF                      [576, 512, 5]
#   5                 4  1    131584  models.common.Conv                      [512, 256, 1, 1]
#   6                 2  1      5376  models.common.Conv                      [40, 128, 1, 1]
#   7                 1  1      1664  models.common.Conv                      [24, 64, 1, 1]
#   8                 5  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#   9            [6, 8]  1         0  models.common.Concat                    [1]
# ...

# %%
import torch
x = torch.randn(1, 3, 640, 640)
y = m(x)
print([t.shape for t in y])
# Out:
# [torch.Size([1, 3, 80, 80, 8]), torch.Size([1, 3, 40, 40, 8]), torch.Size([1, 3, 20, 20, 8])]
